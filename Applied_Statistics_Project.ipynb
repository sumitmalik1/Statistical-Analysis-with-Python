# %% [markdown]
# # Customer Purchase Behavior Analysis using Descriptive Statistics

# %% [markdown]
# 🎯 **Objective**:
#
# The mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Our goal is to identify patterns, trends, and correlations that will help the company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %% [markdown]
# ##About the Dataset

# %% [markdown]
# Here's the link to the [dataset](https://docs.google.com/spreadsheets/d/12ln9iTNcVNOMYi_AU-OczKpa_KIP8XyVbsjk81Na8Yk/edit?usp=sharing)
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# - **Clean and preprocess the dataset (handling missing values, data types, etc.).**
#
# - **Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.**

# %% [markdown]
# **Deliverables**:
#
# 1. **Cleaned and Preprocessed Dataset**:
#
# 2. **Summary of Basic Statistics**:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\DELL\Downloads\Resume Projects\Python EDA Project Customer-Purchase-Behavior-Analysis\Superstore Marketing Data - Sheet1.csv')

# %%
data = df.copy()

# %%
data.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3    ########        0        10  ...                0                 0
# 4    ########        0         6  ...               11                 0
#
# ...

# %%
data.tail()
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 2235         1    ########       99       372  ...               47
# 2236         0   1/22/2013       99         5  ...                3
# 2237         0    ########       99       185  ...               15
# 2238         0  11/29/2012       99       267  ...              149
# 2239         2    ########       99       169  ...              188
#
#       MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# ...

# %%
df = df[~df['Dt_Customer'].str.contains("########")]

# %%
df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 5      7348        1958         PhD         Single  71691.0        0
# 6      4073        1954    2n Cycle        Married  63564.0        0
# ...     ...         ...         ...            ...      ...      ...
# 2230   3363        1974    2n Cycle        Married  20130.0        0
# 2233   7829        1900    2n Cycle       Divorced  36640.0        1
# 2234   9977        1973  Graduation       Divorced  78901.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %%
data.describe()
# Out:
#                  Id   Year_Birth         Income      Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2216.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# std     3246.662198    11.984069   25173.076661     0.538398     0.544538
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35303.000000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51381.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68522.000000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
data.shape
# Out:
# (2240, 22)

# %%
data.columns
# Out:
# Index(['Id', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Response', 'Complain'],
#       dtype='object')

# %% [markdown]
# # **Check for Duplicates**

# %%
dup = len(df[df.duplicated()])

# %%
dup
# Out:
# 0

# %%
df = df[~df['Dt_Customer'].str.contains("########")]

# %%
df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 5      7348        1958         PhD         Single  71691.0        0
# 6      4073        1954    2n Cycle        Married  63564.0        0
# ...     ...         ...         ...            ...      ...      ...
# 2230   3363        1974    2n Cycle        Married  20130.0        0
# 2233   7829        1900    2n Cycle       Divorced  36640.0        1
# 2234   9977        1973  Graduation       Divorced  78901.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %% [markdown]
# #**Handling missing values**

# %%
column_with_nan = data.isnull().sum().sort_values(ascending=False)

# %%
column_with_nan
# Out:
# Income                 24
# Id                      0
# MntFishProducts         0
# Response                0
# NumWebVisitsMonth       0
# NumStorePurchases       0
# NumCatalogPurchases     0
# NumWebPurchases         0
# NumDealsPurchases       0
# MntGoldProds            0
# MntSweetProducts        0
# MntMeatProducts         0
# Year_Birth              0
# MntFruits               0
# MntWines                0
# Recency                 0
# Dt_Customer             0
# Teenhome                0
# Kidhome                 0
# Marital_Status          0
# Education               0
# Complain                0
# dtype: int64

# %%
data["Income"].fillna(value =0, inplace = True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11248\2490478556.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Income"].fillna(value =0, inplace = True)

# %%
data.isnull().sum().sort_values(ascending = False)
# Out:
# Id                     0
# Year_Birth             0
# Response               0
# NumWebVisitsMonth      0
# NumStorePurchases      0
# NumCatalogPurchases    0
# NumWebPurchases        0
# NumDealsPurchases      0
# MntGoldProds           0
# MntSweetProducts       0
# MntFishProducts        0
# MntMeatProducts        0
# MntFruits              0
# MntWines               0
# Recency                0
# Dt_Customer            0
# Teenhome               0
# Kidhome                0
# Income                 0
# Marital_Status         0
# Education              0
# Complain               0
# dtype: int64

# %%
data.shape
# Out:
# (2240, 22)

# %% [markdown]
# ## **AGE OF CUSTOMERS**

# %%
df['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'])

# %%
from datetime import datetime

df['Year_Birth'] = pd.to_datetime(df['Year_Birth'],format='%Y')

#Calculating the age of customers by taking a difference between their year of birth and enrollment

df['Age'] = (df['Dt_Customer'] - df['Year_Birth']).dt.days / 365.25
df['Age'] = df['Age'].round().astype(int)

# %%
df.head()
# Out:
#       Id Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826 1970-01-01  Graduation       Divorced  84835.0        0         0
# 1      1 1961-01-01  Graduation         Single  57091.0        0         0
# 2  10476 1958-01-01  Graduation        Married  67267.0        0         1
# 5   7348 1958-01-01         PhD         Single  71691.0        0         0
# 6   4073 1954-01-01    2n Cycle        Married  63564.0        0         0
#
#   Dt_Customer  Recency  MntWines  ...  MntSweetProducts  MntGoldProds  \
# 0  2014-06-16        0       189  ...               189           218
# 1  2014-06-15        0       464  ...                 0            37
# 2  2014-05-13        0       134  ...                 2            30
# 5  2014-03-17        0       336  ...                32            43
# 6  2014-01-29        0       769  ...                34            65
#
#    NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# ...

# %%
Cust_Age_group = data['Year_Birth'].value_counts()

# %%
Cust_Age_group.head(10)
# Out:
# Year_Birth
# 1976    89
# 1971    87
# 1975    83
# 1972    79
# 1970    77
# 1978    77
# 1965    74
# 1973    74
# 1969    71
# 1974    69
# Name: count, dtype: int64

# %% [markdown]
# We can see that people born in 1976 have are more in the dataset with a number of 89 followed by 1971,75 etc..
# However people born before 1950 are neglible from the dataset.

# %%
edu = data['Education'].value_counts()

# %%
edu
# Out:
# Education
# Graduation    1127
# PhD            486
# Master         370
# 2n Cycle       203
# Basic           54
# Name: count, dtype: int64

# %%
martial = data['Marital_Status'].value_counts()

# %%
martial
# Out:
# Marital_Status
# Married     864
# Together    580
# Single      480
# Divorced    232
# Widow        77
# Alone         3
# YOLO          2
# Absurd        2
# Name: count, dtype: int64

# %% [markdown]
# ## **Various Distributions of the important variables**

# %%
imp_variables = ['Age','Education','Income','Marital_Status']

fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (15,12))
fig.suptitle('Various Distributions of the important variables', y = 0.96 ,color = 'g', fontsize = 25)

axes = axes.flatten()

for i, var in enumerate(df[imp_variables]):
  sns.histplot(df[var], kde = True, ax = axes[i], color = 'g')
  axes[i].set_title(f"Distribution of {var}" , y = 0.92 )

for i in range(len(df[imp_variables]), len(axes)):
  fig.delaxes(axes[i])

plt.tight_layout
plt.show()

# %% [markdown]
# Descriptive Statistics 📊
#
# - **Calculating measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation) for key variables. Identify and handle outliers if necessary.**

# %% [markdown]
# ## **MEAN**

# %%
numeric_columns = data.select_dtypes(include=['number']).columns

mean_value = data[numeric_columns].mean()
print(f"Mean of the variables are :\n {mean_value}")
# Out:
# Mean of the variables are :
#  Id                      5592.159821
# Year_Birth              1968.805804
# Income                 51687.459375
# Kidhome                    0.444196
# Teenhome                   0.506250
# Recency                   49.109375
# MntWines                 303.935714
# MntFruits                 26.302232
# MntMeatProducts          166.950000
# MntFishProducts           37.525446
# MntSweetProducts          27.062946
# MntGoldProds              44.021875
# NumDealsPurchases          2.325000
# NumWebPurchases            4.084821
# NumCatalogPurchases        2.662054
# NumStorePurchases          5.790179
# NumWebVisitsMonth          5.316518
# Response                   0.149107
# Complain                   0.009375
# dtype: float64

# %% [markdown]
# ## **Since there are multiple data types it is better to have a selected list of numeric value for calculating the central tendencies and dispersion.**

# %%
selected_list = ['Age','Income','Recency','MntWines','MntFruits','MntMeatProducts','MntFishProducts','NumDealsPurchases','MntGoldProds','NumWebPurchases','NumWebVisitsMonth']

# %%
mean = df[selected_list].mean()
print(f"Mean of the variables are :\n {mean}")
# Out:
# Mean of the variables are :
#  Age                     44.836103
# Income               51429.747521
# Recency                 49.348187
# MntWines               301.964502
# MntFruits               25.218278
# MntMeatProducts        162.177492
# MntFishProducts         36.485650
# NumDealsPurchases        2.325529
# MntGoldProds            44.107251
# NumWebPurchases          4.092145
# NumWebVisitsMonth        5.409366
# dtype: float64

# %%
mean_data = pd.DataFrame({'Category': mean.index, 'Mean': mean.values})

# %%
mean_data
# Out:
#              Category          Mean
# 0                 Age     44.836103
# 1              Income  51429.747521
# 2             Recency     49.348187
# 3            MntWines    301.964502
# 4           MntFruits     25.218278
# 5     MntMeatProducts    162.177492
# 6     MntFishProducts     36.485650
# 7   NumDealsPurchases      2.325529
# 8        MntGoldProds     44.107251
# 9     NumWebPurchases      4.092145
# 10  NumWebVisitsMonth      5.409366

# %% [markdown]
# ## **MEDIAN**

# %%
median = df[selected_list].median()
print(f"Median of the variables are :\n {median}")
# Out:
# Median of the variables are :
#  Age                     44.0
# Income               50447.0
# Recency                 50.0
# MntWines               171.0
# MntFruits                7.0
# MntMeatProducts         65.5
# MntFishProducts         11.0
# NumDealsPurchases        2.0
# MntGoldProds            24.5
# NumWebPurchases          4.0
# NumWebVisitsMonth        6.0
# dtype: float64

# %%
med_data = pd.DataFrame({'Category': median.index, 'Median': median.values})

# %%
med_data
# Out:
#              Category   Median
# 0                 Age     44.0
# 1              Income  50447.0
# 2             Recency     50.0
# 3            MntWines    171.0
# 4           MntFruits      7.0
# 5     MntMeatProducts     65.5
# 6     MntFishProducts     11.0
# 7   NumDealsPurchases      2.0
# 8        MntGoldProds     24.5
# 9     NumWebPurchases      4.0
# 10  NumWebVisitsMonth      6.0

# %% [markdown]
# ## **MODE**
#
# 1.   List item
# 2.   List item

# %%
key_variable2 = ['Kidhome','Teenhome','MntWines','NumWebVisitsMonth','Complain','Response','Income',"Age"]
mode = df[key_variable2].mode()
print(f'mode of salected columns of datasets are:\n {mode}')
# Out:
# mode of salected columns of datasets are:
#     Kidhome  Teenhome  MntWines  NumWebVisitsMonth  Complain  Response  \
# 0      0.0       0.0       2.0                7.0       0.0       0.0
# 1      NaN       NaN       NaN                NaN       NaN       NaN
#
#     Income   Age
# 0   7500.0  42.0
# 1  35860.0   NaN

# %% [markdown]
# ## **MEASURES OF DISPERSION**

# %% [markdown]
# ## **VARIANCE**

# %%
selected_list = ['Age','Income','Recency','MntWines','MntFruits','MntMeatProducts','MntFishProducts','NumDealsPurchases','MntGoldProds','NumWebPurchases','NumWebVisitsMonth']

Variance = df[selected_list].var()
print(f"Variance of selected items are :\n {Variance}")
# Out:
# Variance of selected items are :
#  Age                  1.474493e+02
# Income               4.393294e+08
# Recency              8.303541e+02
# MntWines             1.145089e+05
# MntFruits            1.489002e+03
# MntMeatProducts      4.805031e+04
# MntFishProducts      2.962155e+03
# NumDealsPurchases    3.672485e+00
# MntGoldProds         2.785360e+03
# NumWebPurchases      7.701253e+00
# NumWebVisitsMonth    5.935090e+00
# dtype: float64

# %% [markdown]
# ## **STANDARD DEVIATION**

# %%
standard_deviation = df[selected_list].std()
print(f"Standard deviation of selected items are : \n {standard_deviation}")
# Out:
# Standard deviation of selected items are :
#  Age                     12.142871
# Income               20960.186407
# Recency                 28.815866
# MntWines               338.391676
# MntFruits               38.587591
# MntMeatProducts        219.203801
# MntFishProducts         54.425681
# NumDealsPurchases        1.916373
# MntGoldProds            52.776506
# NumWebPurchases          2.775113
# NumWebVisitsMonth        2.436204
# dtype: float64

# %% [markdown]
# ## **HANDLING OUTLIERS USING BOXPLOT**

# %%
key_variables = ['Income', 'Age', 'MntWines', 'MntFruits', 'MntMeatProducts','Recency']

length_of_variables = len(key_variables)

rows_number = (length_of_variables + 1) // 2

fig, axes = plt.subplots(nrows = rows_number, ncols = 2, figsize = (12,8))

axes = axes.flatten()

for i, var in enumerate(key_variables):
  sns.boxplot(x = var, data = df, ax = axes[i], color = 'g')
  axes[i].set_title(f'Boxplot of {var}:', y = 0.98, color = 'black',fontsize = 15)

plt.tight_layout()
plt.show()

# %%
columns_with_outliers = ['Income', 'Age', 'MntWines', 'MntFruits', 'MntMeatProducts']

def remove_outliers(data,columns):

    for column in columns:
        Q1 = data[column].quantile(0.20)
        Q3 = data[column].quantile(0.80)
        IQR = Q3  - Q1

#Defining the lower and upper bounds

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3  + 1.5 * IQR

        data = data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]

    return data

# %%
new_df = remove_outliers(df,columns_with_outliers)
new_df
# Out:
#          Id Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 1         1 1961-01-01  Graduation         Single  57091.0        0         0
# 2     10476 1958-01-01  Graduation        Married  67267.0        0         1
# 6      4073 1954-01-01    2n Cycle        Married  63564.0        0         0
# 7      1991 1967-01-01  Graduation       Together  44931.0        0         1
# 10     2079 1947-01-01    2n Cycle        Married  81044.0        0         0
# ...     ...        ...         ...            ...      ...      ...       ...
# 2228   7947 1969-01-01  Graduation        Married  42231.0        1         1
# 2229   2106 1974-01-01    2n Cycle        Married  20130.0        0         0
# 2230   3363 1974-01-01    2n Cycle        Married  20130.0        0         0
# 2234   9977 1973-01-01  Graduation       Divorced  78901.0        0         1
# 2236   5263 1977-01-01    2n Cycle        Married  31056.0        1         0
#
# ...

# %%
key_variables = ['Recency','Age','Income']

length_of_variables = len(key_variables)

fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (12,8))

axes = axes.flatten()

for i, variable in enumerate(key_variables):
  sns.boxplot(x = variable, data = new_df, ax = axes[i], color = 'g')
  axes[i].set_title(f'Boxplot of {variable}:', y = 0.90, color = 'black',fontsize = 15)

plt.show()

# %% [markdown]
# ## Probability Distributions 🎲

# %% [markdown]
# ## **Normal Distributions**

# %%
import numpy as np
import scipy.stats as stats

variable_1 = ['Age','Recency','Income']

fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (12,8))
fig.suptitle(" Normal Distribution curves of variable_1", y = 0.98, color = 'g')

axes = axes.flatten()

for i , var in enumerate(variable_1):
  sns.histplot(new_df[var], kde = True, ax = axes[i], color = 'green')
  axes[i].set_title(f'Distribution of {var}:')

for i in range(len(variable_1), len(axes)):
  fig.delaxes(axes[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Probability and Expected Value**

# %%
import numpy as np
from scipy.stats import norm

# %%
mean_recency = np.mean(new_df['Recency'])
std_recency = np.std(new_df['Recency'])

prob_less_than_20 = norm.cdf(20, loc = mean_recency, scale = std_recency)
prob_greater_than_20 = 1 - norm.cdf(21, loc = mean_recency, scale = std_recency)

print(f"Probability of recency less than 20: {prob_less_than_20:.3f}:")
print(f"Probability of recency less than 20: {prob_greater_than_20:.3f}:")


#expected value

expected_value = mean_recency
print(f"The expected value is: {expected_value:.2f}")
# Out:
# Probability of recency less than 20: 0.157:
# Probability of recency less than 20: 0.835:
# The expected value is: 48.95

# %%
new_df
# Out:
#          Id Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 1         1 1961-01-01  Graduation         Single  57091.0        0         0
# 2     10476 1958-01-01  Graduation        Married  67267.0        0         1
# 6      4073 1954-01-01    2n Cycle        Married  63564.0        0         0
# 7      1991 1967-01-01  Graduation       Together  44931.0        0         1
# 10     2079 1947-01-01    2n Cycle        Married  81044.0        0         0
# ...     ...        ...         ...            ...      ...      ...       ...
# 2228   7947 1969-01-01  Graduation        Married  42231.0        1         1
# 2229   2106 1974-01-01    2n Cycle        Married  20130.0        0         0
# 2230   3363 1974-01-01    2n Cycle        Married  20130.0        0         0
# 2234   9977 1973-01-01  Graduation       Divorced  78901.0        0         1
# 2236   5263 1977-01-01    2n Cycle        Married  31056.0        1         0
#
# ...

# %%
# calculating for income now:

mean_Income = np.mean(new_df['Income'])
std_Income = np.std(new_df['Income'])

prob_less_than_50000 = norm.cdf(50000, loc = mean_Income, scale = std_Income)
prob_greater_than_50000 = 1 - norm.cdf(50001, loc = mean_Income, scale = std_Income)

print(f"Probability of Income lesser than $50000: {prob_less_than_50000:.3f}:")
print(f"Probability of Income greater than $50000: {prob_greater_than_50000:.3f}:")

#expected value

expected_value = mean_Income
print(f"The expected value is: {expected_value:.2f}")
# Out:
# Probability of Income lesser than $50000: 0.552:
# Probability of Income greater than $50000: 0.448:
# The expected value is: 47529.71

# %% [markdown]
# Here the Age can be  divided into Adults ,Teens and Kids. if Age >18 then adults less than 18 but greater then 13 then teens else kids

# %%
mean_Age = np.mean(new_df['Age'])
std_Age = np.std(new_df['Age'])


Age_lesser_than_18 = norm.cdf(18, loc = mean_Age, scale =std_Age )
Age_greater_than_18 = 1 - norm.cdf(19, loc = mean_Age, scale =std_Age )

print(f"Probability of Age lesser than 18: {Age_lesser_than_18:.3f}:")
print(f"Probability of Age greater than 18: {Age_greater_than_18:.3f}:")

#expected value

expected_value = mean_Age
print(f"The expected value is: {expected_value:.2f}")
# Out:
# Probability of Age lesser than 18: 0.010:
# Probability of Age greater than 18: 0.987:
# The expected value is: 44.61

# %% [markdown]
# ## **Binomial Distribution**

# %%
key_variable_2 = ['Response','Complain']

fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (12,8))
fig.suptitle("  key_variables which follows Binomial Distribution ", y = 0.98, color = 'g')

axes = axes.flatten()

for i , var in enumerate(key_variable_2):
  sns.histplot(new_df[var], kde = True, ax = axes[i], color = 'green')
  axes[i].set_title(f'Distribution of {var}:')

for i in range(len(key_variable_2), len(axes)):
  fig.delaxes(axes[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Probability and Expected Value**

# %%
new_df
# Out:
#          Id Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 1         1 1961-01-01  Graduation         Single  57091.0        0         0
# 2     10476 1958-01-01  Graduation        Married  67267.0        0         1
# 6      4073 1954-01-01    2n Cycle        Married  63564.0        0         0
# 7      1991 1967-01-01  Graduation       Together  44931.0        0         1
# 10     2079 1947-01-01    2n Cycle        Married  81044.0        0         0
# ...     ...        ...         ...            ...      ...      ...       ...
# 2228   7947 1969-01-01  Graduation        Married  42231.0        1         1
# 2229   2106 1974-01-01    2n Cycle        Married  20130.0        0         0
# 2230   3363 1974-01-01    2n Cycle        Married  20130.0        0         0
# 2234   9977 1973-01-01  Graduation       Divorced  78901.0        0         1
# 2236   5263 1977-01-01    2n Cycle        Married  31056.0        1         0
#
# ...

# %%
from scipy.stats import binom

num_response = len(df['Response']) # Num of trails for a response
success_response = np.mean(df['Response']) # probability of success for Response
k1 = np.sum(df['Response'] == 1)  # No of success for getting response 1


num_Complain = len(df['Complain']) # Num of trails for a Complain
success_Complain = np.mean(df['Complain']) # probability of success for Complain
k2 = np.sum(df['Complain'] == 1) # No of success for getting complain 1

#probabilities of complain and responses are

prob_response = binom.pmf(k1,num_response,success_response)
prob_complain = binom.pmf(k2,num_Complain,success_Complain)

print(f"The probability of Response being 1 : {prob_response:.2f}")
print(f"The probability of Complain being 1 : {prob_complain:.2f}")

# Expected value

expected_response = num_response * success_response
expected_complain = num_Complain * success_Complain

print(f"The Expected value of Response is : {expected_response:.2f}")
print(f"The Expected value of Complain is: {expected_complain:.2f}")
# Out:
# The probability of Response being 1 : 0.03
# The probability of Complain being 1 : 0.11
# The Expected value of Response is : 200.00
# The Expected value of Complain is: 12.00

# %% [markdown]
# ## Customer Segmentation 📈
#
# - **Exploring relationships between customer characteristics and spending habits. Segment customers based on their behaviors and characteristics.**

# %% [markdown]
# ## **Grouped Bar chart for Education and Marital Status Distribution**

# %%
plt.figure(figsize = (12,8))
sns.countplot(x = 'Education', data = new_df , hue = 'Marital_Status', palette = 'Paired')
plt.title("Education vs Marital_Status Distribution")
plt.xlabel('Education')
plt.ylabel('Count')
plt.legend(fontsize = 15)
plt.show()

# %% [markdown]
# ## **Age vs Income**

# %%
plt.figure(figsize = (12,8))
sns.lineplot(x = 'Age', data = new_df , y = 'Income')
plt.title("Age vs Income Distribution")
plt.xlabel('Age')
plt.ylabel('Income')
plt.legend(fontsize = 15)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11248\2543420290.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize = 15)

# %% [markdown]
# It is evident that people who are in 20's and 70's have their income high and people between 20's and 70's have moderate income.

# %% [markdown]
# Now atlast to show the correlation between the variables we plot correlation plot

# %%
new_df
# Out:
#          Id Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 1         1 1961-01-01  Graduation         Single  57091.0        0         0
# 2     10476 1958-01-01  Graduation        Married  67267.0        0         1
# 6      4073 1954-01-01    2n Cycle        Married  63564.0        0         0
# 7      1991 1967-01-01  Graduation       Together  44931.0        0         1
# 10     2079 1947-01-01    2n Cycle        Married  81044.0        0         0
# ...     ...        ...         ...            ...      ...      ...       ...
# 2228   7947 1969-01-01  Graduation        Married  42231.0        1         1
# 2229   2106 1974-01-01    2n Cycle        Married  20130.0        0         0
# 2230   3363 1974-01-01    2n Cycle        Married  20130.0        0         0
# 2234   9977 1973-01-01  Graduation       Divorced  78901.0        0         1
# 2236   5263 1977-01-01    2n Cycle        Married  31056.0        1         0
#
# ...

# %%
numeric_df = new_df.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr().round(2)
plt.figure(figsize = (12,8))
sns.heatmap(correlation_matrix,annot =True, cmap = 'rainbow', linewidths = 0.5)
plt.title('Correlation_Map')
plt.show()

# %% [markdown]
# **Key insights regarding relationships between variables and distinct customer segments based on behaviors.**

# %% [markdown]
# ## Conclusion and Recommendations

# %% [markdown]
# ## **Trends of visitors across the month on website**

# %%
new_df
# Out:
#          Id Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 1         1 1961-01-01  Graduation         Single  57091.0        0         0
# 2     10476 1958-01-01  Graduation        Married  67267.0        0         1
# 6      4073 1954-01-01    2n Cycle        Married  63564.0        0         0
# 7      1991 1967-01-01  Graduation       Together  44931.0        0         1
# 10     2079 1947-01-01    2n Cycle        Married  81044.0        0         0
# ...     ...        ...         ...            ...      ...      ...       ...
# 2228   7947 1969-01-01  Graduation        Married  42231.0        1         1
# 2229   2106 1974-01-01    2n Cycle        Married  20130.0        0         0
# 2230   3363 1974-01-01    2n Cycle        Married  20130.0        0         0
# 2234   9977 1973-01-01  Graduation       Divorced  78901.0        0         1
# 2236   5263 1977-01-01    2n Cycle        Married  31056.0        1         0
#
# ...

# %%
new_df['month'] = new_df['Dt_Customer'].dt.strftime('%B')

# %%
new_df['Day'] = new_df['Dt_Customer'].dt.strftime('%A')

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June',
    'July', 'August', 'September', 'October', 'November', 'December']

new_df['month'] = pd.Categorical(new_df['month'], categories = months, ordered = True)

plt.figure(figsize = (12,12))
sns.lineplot(x = 'month', y = 'NumWebVisitsMonth', data = new_df.groupby('month')['NumWebVisitsMonth'].sum().reset_index(), color = 'green')
plt.title("Trends of visitors across the month on website")
plt.xticks(rotation = 45)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11248\1629172711.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sns.lineplot(x = 'month', y = 'NumWebVisitsMonth', data = new_df.groupby('month')['NumWebVisitsMonth'].sum().reset_index(), color = 'green')

# %% [markdown]
# We can incurr from the graph that the highest purchase is made on the month of
#
# ---
#
# August and lowest is on July.

# %% [markdown]
# ## **Num of purchases made aacross the months through website**

# %%
plt.figure(figsize = (12,12))

sns.barplot(x = 'month', y = 'NumWebPurchases', data = new_df.groupby('month')['NumWebPurchases'].sum().reset_index(),  palette = 'viridis')
plt.title("Num of purchases made aacross the months through website")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11248\106067131.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sns.barplot(x = 'month', y = 'NumWebPurchases', data = new_df.groupby('month')['NumWebPurchases'].sum().reset_index(),  palette = 'viridis')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11248\106067131.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'month', y = 'NumWebPurchases', data = new_df.groupby('month')['NumWebPurchases'].sum().reset_index(),  palette = 'viridis')

# %% [markdown]
# We can incurr from the graph that the highest purchase is made on the month of August and lowest is on July.

# %%
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

new_df['Day'] = pd.Categorical(new_df['Day'], categories = days, ordered = True)

plt.figure(figsize = (15,12))
sns.lineplot(x = 'Day', y = 'NumWebPurchases', data = new_df.groupby('Day')['NumWebPurchases'].sum().reset_index(), color = 'green')
plt.title("Purchases on each day ")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11248\1817704231.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sns.lineplot(x = 'Day', y = 'NumWebPurchases', data = new_df.groupby('Day')['NumWebPurchases'].sum().reset_index(), color = 'green')

# %% [markdown]
# We can see that the purchases are high on Wednesday and low on Thursday.

# %%
new_df['TotalSpending'] = new_df[['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']].sum(axis=1)

# %%
plt.figure(figsize = (12,5))
color = ['green','orange','yellow','blue','magenta','grey','black']
sns.scatterplot(x='Income', y='TotalSpending', hue='Marital_Status', data = new_df, palette = color)
plt.title('Scatter Plot of Income vs MntWines')
plt.show()

# %% [markdown]
# We can see that as income increases the total spending also increases which is directly proportional in nature.
#
# > Indented block

# %% [markdown]
# ## **Conclusion and Recommendations**

# %% [markdown]
# ### **1.	Recommendations based on Statistical Analysis:**
#
# •	Expected income(Mean) is 47529 which is an indication that the marketing team should focus on promoting mid range products to enhance their profits.
#
# •	Expected Age of customer is 44 years. Here the company should focus more on these age groups (40-45) to encourage more purchases as their incomes are high.
#
# ## **2.	Area's to be improved based on EDA**
#
# •	The Highest Number of customers visiting the website and purchasing a product is during August and Lowest is for July. Hence the company should employ more number of staff for marketing team in the month of july and should  be active in promoting ads and emails to encourage more purchasing in during this month.
#
# •	People with Graduation and phd are most likely to spend because of their high income.
#
# •	Customers who spend most on Wines also spend on buying Meat products hence the company should give attractive and complimentry offers and suggestion so that more num of people buy these projects and increase the profit  to the company.
#
# •	Customers who are either Married or together is most likely to spend more. Hence compaany should provide attractive offers and incenticize them through complimentary gifts and other couple related program.
